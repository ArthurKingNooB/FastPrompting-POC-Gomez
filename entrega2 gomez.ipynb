# %% [markdown]
# # Entrega 2 — Fast Prompting en Acción
# **Curso: IA — Generación de Prompts**
# **Autor: Camilo Gómez**
#
# ---
#
# ## Introducción
# - **Problema**: Los docentes y estudiantes suelen carecer de tiempo para crear material didáctico personalizado y atractivo. Esto impacta en la motivación y el rendimiento
# - **Propuesta**: Generar cuestionarios, resúmenes y explicaciones paso a paso mediante prompts optimizados y el uso de la API de Gemini
# - **Viabilidad**: Uso de Gemini (accesible), alcance acotado y costos bajos gracias a cache y parametrización

# %% [markdown]
# ## Objetivos
# 1. Aplicar técnicas de **Fast Prompting**
# 2. Implementar una **POC en Jupyter Notebook**
# 3. Minimizar las llamadas a la API y registrar métricas
# 4. Probar diferentes tipos de materiales educativos: **quiz, resumen, explicación, prompts de imagen**

# %%
import os
from getpass import getpass
from dotenv import load_dotenv
import google.generativeai as genai


load_dotenv()

API_KEY = os.getenv("GEMINI_API_KEY")


if not API_KEY:
    API_KEY = getpass("Ingresá tu apikey ")

genai.configure(api_key=API_KEY)

print("Gemini configurado correctamente")
# Out:
# Ingresá tu apikey  ········
# Gemini configurado correctamente

# %%
DEFAULT_MODEL = "gemini-1.5-flash"

GENERATION_CONFIG = {
    "temperature": 0.6,
    "top_p": 0.9,
    "top_k": 40,
    "max_output_tokens": 800
}

model = genai.GenerativeModel(
    model_name=DEFAULT_MODEL,
    generation_config=GENERATION_CONFIG
)

# %%
def quiz_prompt(topic, level="secundaria", n=5):
    return f"""
TAREA: Generar cuestionario de autoevaluación
CONTEXTO:
- Tema: {topic}
- Nivel: {level}

REQUISITOS:
- {n} preguntas variadas (múltiple opción o verdadero/falso).
- Incluye la respuesta correcta y una breve justificación.
- Salida en formato JSON válido.

SALIDA (ejemplo):
{{
  "topic": "{topic}",
  "questions": [
    {{"q": "Pregunta 1", "type":"multiple", "options":["a","b"], "answer":"a","why":"..." }}
  ]
}}
"""

def summary_prompt(topic, length="medio", audience="secundaria"):
    return f"""
TAREA: Resumir contenido educativo
CONTEXTO:
- Tema: {topic}
- Audiencia: {audience}
- Longitud: {length}

REQUISITOS:
- Resume en 3-5 ideas clave.
- Incluye un ejemplo práctico.
"""

def explanation_prompt(topic, steps=5):
    return f"""
TAREA: Explicación paso a paso
Tema: {topic}
Pasos: {steps}

REQUISITOS:
- Explica en {steps} pasos claros.
- Incluye al final 3 errores comunes y cómo evitarlos.
"""

def image_prompt(goal, style="educativo, claro, minimalista"):
    return f"""
Genera un prompt para NightCafe u otro generador de imágenes que represente:
"{goal}"
Estilo: {style}.
Debe incluir etiquetas claras y fondo limpio.
"""

# %%
def generate(prompt, task="general", model_name=DEFAULT_MODEL):
    model = genai.GenerativeModel(model_name)
    response = model.generate_content(prompt)
    return response.text

# %%
quiz_text = generate(quiz_prompt("Fotosíntesis"), task="quiz")
print(quiz_text)

print(generate(summary_prompt("Revolución Francesa")))

print(generate(explanation_prompt("Derivadas básicas", steps=5)))

print(generate(image_prompt("El ciclo del agua para primaria")))
# Out:
# ```json
# {
#   "topic": "Fotosíntesis",
#   "questions": [
#     {
#       "q": "¿Cuál es el principal pigmento involucrado en la fotosíntesis?",
#       "type": "multiple",
#       "options": ["a) Clorofila", "b) Carotenoides", "c) Xantofilas", "d) Ficobilinas"],
#       "answer": "a",
#       "why": "La clorofila es el pigmento principal que absorbe la luz solar necesaria para la fotosíntesis. Los carotenoides y xantofilas son pigmentos accesorios."
#     },
#     {
#       "q": "La fotosíntesis ocurre en...",
#       "type": "multiple",
#       "options": ["a) El núcleo celular", "b) Las mitocondrias", "c) Los cloroplastos", "d) El citoplasma"],
#       "answer": "c",
#       "why": "Los cloroplastos son los orgánulos celulares donde se lleva a cabo la fotosíntesis."
#     },
#     {
#       "q": "Verdadero o Falso: La fotosíntesis es un proceso que libera oxígeno como subproducto.",
#       "type": "boolean",
#       "answer": true,
#       "why": "Durante la fase luminosa de la fotosíntesis, se produce la fotólisis del agua, liberando oxígeno como subproducto."
#     },
#     {
#       "q": "¿Cuáles son los principales reactantes (sustancias iniciales) de la fotosíntesis?",
#       "type": "multiple",
#       "options": ["a) Glucosa y oxígeno", "b) Dióxido de carbono y agua", "c) Agua y glucosa", "d) Oxígeno y dióxido de carbono"],
#       "answer": "b",
#       "why": "La fotosíntesis utiliza dióxido de carbono del aire y agua del suelo como reactantes principales para producir glucosa y oxígeno."
#     },
#     {
#       "q": "Verdadero o Falso: La fase oscura de la fotosíntesis requiere luz solar directa para funcionar.",
#       "type": "boolean",
#       "answer": false,
#       "why": "La fase oscura, o ciclo de Calvin, utiliza la energía química (ATP y NADPH) producida durante la fase luminosa, pero no requiere luz solar directamente."
#     }
#   ]
# }
# ```
#
# La Revolución Francesa (1789-1799) puede resumirse en estas 5 ideas clave para estudiantes de secundaria:
#
# 1. **Crisis económica y social:** Francia estaba sumida en una profunda crisis financiera, agravada por una desigualdad social extrema. El Tercer Estado (campesinos, burgueses, etc.) cargaba con la mayor parte de los impuestos, mientras que el clero y la nobleza disfrutaban de privilegios.  Esto generó un gran descontento y alimentó las protestas.
#
# 2. **Lucha por la libertad e igualdad:** Los revolucionarios lucharon por ideales iluministas como la libertad, la igualdad y la fraternidad, rechazando el absolutismo monárquico y el sistema feudal.  Buscaban una sociedad más justa y equitativa, donde los derechos individuales fueran respetados.
#
# 3. **Caída de la monarquía:** La toma de la Bastilla (14 de julio de 1789) simboliza el inicio de la revolución y el fin del poder absoluto del rey Luis XVI.  Su posterior ejecución marca un punto de inflexión radical en el proceso revolucionario.
#
# 4. **El Terror:** El período del Terror (1793-1794), bajo el gobierno de Robespierre, se caracterizó por la violencia y la represión política.  Miles de personas fueron guillotinadas en nombre de la revolución, demostrando la fragilidad del ideal revolucionario y la tendencia a la radicalización.
#
# 5. **Legado duradero:** A pesar de la violencia y la inestabilidad, la Revolución Francesa dejó un legado fundamental: la Declaración de los Derechos del Hombre y del Ciudadano, que inspiró movimientos revolucionarios posteriores e influyó en la configuración de los estados modernos, estableciendo principios como la soberanía popular y la separación de poderes.
#
#
# **Ejemplo práctico:**  Imagina que en tu escuela hay un sistema de reparto de recursos (ej: materiales para proyectos, horas de uso de la sala de informática) donde un pequeño grupo (la nobleza) recibe la mayor parte, mientras que la mayoría (el Tercer Estado) apenas recibe algo.  La lucha por un reparto más justo, con reglas iguales para todos, se asemeja a la lucha del Tercer Estado francés contra la desigualdad y el privilegio durante la Revolución.  La toma de la Bastilla sería como si los estudiantes indignados se apoderaran del almacén de materiales para repartirlos equitativamente.
#
# **Tarea: Derivadas Básicas - Explicación Paso a Paso**
#
# Vamos a aprender a calcular derivadas de funciones básicas en 5 pasos.  Usaremos la notación de Leibniz (dy/dx) que es muy común.
#
#
# **Paso 1: Identificar la regla de derivación aplicable.**
#
# Antes de empezar a calcular, debemos reconocer qué tipo de función tenemos.  Las reglas básicas incluyen:
#
# * **Derivada de una constante:** La derivada de una constante (un número) es siempre cero.  Ejemplo: d/dx (5) = 0
# * **Derivada de una potencia:** La derivada de xⁿ es nxⁿ⁻¹. Ejemplo: d/dx (x³) = 3x²
# * **Derivada de una función lineal:** La derivada de ax + b es a. Ejemplo: d/dx (2x + 7) = 2
# * **Derivada de una suma/resta:** La derivada de una suma o resta de funciones es la suma o resta de sus derivadas. Ejemplo: d/dx (x² + 3x - 2) = 2x + 3
# * **Derivada de un múltiplo constante:** La derivada de una constante multiplicada por una función es la constante multiplicada por la derivada de la función. Ejemplo: d/dx (5x²) = 10x
#
#
# **Paso 2: Aplicar la regla de derivación.**
#
# Una vez identificada la regla apropiada, aplicarla a la función. Asegúrate de aplicar cada regla correctamente a cada parte de la función.
#
#
# **Paso 3: Simplificar la expresión.**
#
# Después de aplicar la regla de derivación, simplifica la expresión resultante. Combina términos semejantes y reduce la fracción si es necesario.
#
#
# **Paso 4: Verificar la respuesta.**
#
# Revisar cuidadosamente el proceso de derivación para identificar posibles errores aritméticos o en la aplicación de las reglas.  Es útil comparar con ejemplos resueltos si hay dudas.
#
#
# **Paso 5:  Escribir la respuesta final.**
#
# Escribe la derivada final de forma clara y concisa, incluyendo la variable independiente (normalmente 'x').
#
#
# **Ejemplo:**  Encontrar la derivada de f(x) = 3x² + 4x - 7
#
# 1. **Identificar:** Tenemos una suma de una potencia, una función lineal y una constante.
# 2. **Aplicar:** Usando las reglas de derivación,  d/dx (3x²) + d/dx (4x) - d/dx (7)
# 3. **Simplificar:**  6x + 4 - 0 = 6x + 4
# 4. **Verificar:** Revisamos cada paso.  La aplicación de la regla de la potencia y lineal son correctas. La derivada de la constante es cero.
# 5. **Respuesta:** f'(x) = 6x + 4
#
#
# **Errores comunes y cómo evitarlos:**
#
# 1. **Error en la regla de la potencia:** Olvidar restar 1 del exponente o equivocarse en el coeficiente.  **Solución:** Practicar con muchos ejemplos y verificar cuidadosamente cada paso.
#
# 2. **No aplicar la regla de la derivada de una suma/resta correctamente:** Tratar la derivada de una suma como la multiplicación de derivadas.  **Solución:** Recordar que la derivada de una suma es la suma de las derivadas.
#
# 3. **Errores aritméticos:**  Errores simples en la multiplicación, división, suma o resta.  **Solución:**  Realizar los cálculos con cuidado y verificar los resultados intermedios.  Utilizar una calculadora si es necesario, pero siempre entender el proceso.
#
# Aquí tienes varios prompts para NightCafe u otro generador de imágenes,  con diferentes enfoques para representar "El ciclo del agua para primaria" de forma educativa, clara y minimalista:
#
#
# **Opción 1 (enfoque diagramático):**
#
# > Un diagrama simple y limpio del ciclo del agua para niños de primaria.  Etiquetas claras para: evaporación, condensación, precipitación, colección. Fondo blanco. Estilo minimalista.  Colores pastel.  Ilustraciones sencillas.  Palabras clave: ciclo hidrológico, agua, nubes, lluvia, río, océano.
#
#
# **Opción 2 (enfoque visual más narrativo):**
#
# > Ilustración minimalista del ciclo del agua. Mostrar el sol evaporando agua del océano, nubes formándose, lluvia cayendo, agua fluyendo a un río, y finalmente regresando al océano.  Etiquetas simples y grandes para cada etapa. Fondo blanco. Colores vibrantes pero suaves. Estilo infantil, educativo.
#
#
# **Opción 3 (Más abstracto, pero aún claro):**
#
# > Representación abstracta del ciclo del agua para niños de primaria.  Usar formas geométricas simples y colores para representar evaporación, condensación, precipitación y colección.  Etiquetas claras y concisas. Fondo blanco o muy claro.  Estilo minimalista y educativo.
#
#
# **Opción 4 (Específico para NightCafe, usando sus estilos):**
#
# >  `style: minimalist, educational, children's book illustration`  El ciclo del agua.  Mostrar: evaporación (sol calentando el océano), condensación (nubes), precipitación (lluvia), colección (río, océano).  Etiquetas grandes y legibles.  Fondo blanco.
#
#
# Recuerda que puedes ajustar estos prompts añadiendo más detalles según tus preferencias.  Por ejemplo, podrías especificar el tipo de fuente, el número de etiquetas, o colores específicos.  Experimentar con diferentes prompts te ayudará a obtener el resultado que buscas.

# %% [markdown]
# ## Evaluación de costos y conclusiones
# - Uso de **gemini-1.5-flash** para iteraciones rápidas
# - Control de parámetros y uso de **prompts cortos** evita costos innecesarios
# - Posible mejora: implementar **cache** para reusar respuestas idénticas
# - Conclusión: el Fast Prompting permitió generar quizzes, resúmenes y explicaciones de manera rápida, estructurada y optimizada
